# %% [markdown]
# # GAME OF THRONES

# %% [markdown]
# <img src="http://www.jamiesale-cartoonist.com/wp-content/uploads/characters.png">

# %% [markdown]
# ## YOU WIN YOU DIE

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd

# %% [markdown]
# ## Cargar datos para crear un DataFrame

# %%
data_got = pd.read_csv('character-deaths.csv')

# %% [markdown]
# ## Primera vista a los datos

# %%
data_got
# Out:
#                                   Name      Allegiances  Death Year  \
# 0                       Addam Marbrand        Lannister         NaN
# 1              Aegon Frey (Jinglebell)             None       299.0
# 2                      Aegon Targaryen  House Targaryen         NaN
# 3                        Adrack Humble    House Greyjoy       300.0
# 4                       Aemon Costayne        Lannister         NaN
# 5                      Aemon Estermont        Baratheon         NaN
# 6    Aemon Targaryen (son of Maekar I)    Night's Watch       300.0
# 7                           Aenys Frey             None       300.0
# 8                        Aeron Greyjoy    House Greyjoy         NaN
# 9                               Aethan    Night's Watch         NaN
# 10                               Aggar    House Greyjoy       299.0
# 11                                Aggo  House Targaryen         NaN
# 12                       Alan of Rosby    Night's Watch       300.0
# ...

# %% [markdown]
# ## Año de muerte promedio

# %%
data_got['Death Year'].mean()
# Out:
# 299.15737704918035

# %% [markdown]
# ## Estadístico del año de muerte

# %%
# %matplotlib inline

# %%
data_got['Death Year'].hist()

# %% [markdown]
# ## Para estar seguro:

# %%
data_got['Death Year'].min()
# Out:
# 297.0

# %%
data_got['Death Year'].max()
# Out:
# 300.0

# %% [markdown]
# ## Muertos de los Stark incluyendo aliados

# %%
(data_got['Allegiances']=='House Stark').value_counts()+(data_got['Allegiances']=='Stark').value_counts()
# Out:
# False    1726
# True      108
# Name: Allegiances, dtype: int64
